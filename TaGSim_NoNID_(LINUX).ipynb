# %% [markdown]
# <a href="https://colab.research.google.com/github/neuralresearch/CS39-6/blob/henry/TaGSim_NoNID_(LINUX).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import ast
print(sys.executable)
import os
import random
import networkx as nx
from matplotlib import pyplot as plt
import pylab
import re
import torch
import numpy as np
import pandas as pd
# 1.nr 2.nid 3.er 4.eid
# Out:
# /usr/bin/python3

# %%
# Code to download file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#get the data from the drive https://drive.google.com/file/d/1YiX2r2glQ4r1hiy7BqAkSRyGvuPqBcne/view?usp=share_link
id = '1YiX2r2glQ4r1hiy7BqAkSRyGvuPqBcne'
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('LINUX.zip')
# !ls
# Out:
# LINUX.zip  sample_data

# %%
# !unzip /content/LINUX.zip
# Out:
# Archive:  /content/LINUX.zip
#   inflating: generated/00000_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00001_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00002_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00003_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00004_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00005_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00006_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00007_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00008_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00009_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00011_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00012_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00013_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00014_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00015_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00016_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00017_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00018_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00019_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00020_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00021_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00022_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00023_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00024_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00025_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00026_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00027_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00028_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00031_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00032_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00033_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00034_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00035_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00036_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00037_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00038_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00040_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00041_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00042_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00043_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00044_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00045_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00046_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00047_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00048_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00049_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00050_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00051_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00052_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00053_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00054_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00055_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00056_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00057_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00058_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00059_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00060_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00061_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00062_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00063_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00064_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00065_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00066_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00067_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00068_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00069_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00070_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00071_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00072_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00074_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00075_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00076_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00077_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00078_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00079_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00080_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00081_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00082_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00083_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00084_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00085_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00086_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00087_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00088_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00089_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00090_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00091_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00092_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00093_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00095_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00096_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00097_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00099_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00100_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00101_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00102_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00103_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00105_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00106_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00107_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00108_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00109_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00110_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00111_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00112_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00113_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00114_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00115_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00116_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00117_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00119_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00120_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00121_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00122_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00123_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00126_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00127_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00128_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00129_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00131_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00132_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00133_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00134_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00135_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00136_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00137_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00138_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00139_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00140_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00141_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00142_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00143_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00144_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00145_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00146_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00148_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00149_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00150_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00151_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00152_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00153_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00154_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00155_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00156_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00157_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00158_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00159_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00160_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00161_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00162_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00164_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00165_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00166_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00167_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00168_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00169_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00171_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00172_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00173_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00174_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00175_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00177_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00178_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00179_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00180_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00182_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00183_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00184_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00185_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00186_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00187_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00189_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00190_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00191_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00192_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00193_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00194_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00195_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00196_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00197_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00199_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00200_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00201_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00202_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00204_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00205_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00206_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00207_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00208_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00209_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00210_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00211_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00212_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00213_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00214_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00217_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00219_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00220_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00221_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00222_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00223_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00225_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00226_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00227_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00228_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00229_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00230_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00231_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00232_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00233_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00234_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00235_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00236_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00237_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00238_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00239_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00240_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00241_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00242_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00243_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00244_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00245_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00246_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00247_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00249_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00250_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00251_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00252_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00253_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00254_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00255_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00256_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00257_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00258_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00259_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00260_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00261_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00262_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00263_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00264_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00265_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00266_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00267_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00268_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00269_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00270_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00271_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00273_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00274_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00275_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00276_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00277_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00278_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00279_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00280_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00281_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00282_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00283_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00284_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00285_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00286_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00287_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00288_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00289_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00291_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00292_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00293_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00294_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00295_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00296_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00297_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00298_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00299_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00300_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00301_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00302_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00303_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00304_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00306_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00307_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00308_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00309_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00310_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00311_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00312_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00313_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00314_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00315_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00316_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00317_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00318_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00319_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00320_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00321_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00322_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00323_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00324_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00325_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00326_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00327_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00328_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00329_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00330_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00331_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00332_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00333_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00334_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00335_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00336_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00339_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00341_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00342_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00343_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00344_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00345_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00347_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00349_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00350_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00351_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00352_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00353_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00354_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00355_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00356_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00357_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00359_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00360_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00361_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00362_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00363_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00365_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00366_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00367_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00368_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00369_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00370_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00371_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00372_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00373_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00374_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00375_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00376_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00377_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00378_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00379_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00380_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00381_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00382_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00384_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00385_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00387_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00388_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00389_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00390_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00391_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00392_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00393_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00394_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00396_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00397_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00398_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00399_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00400_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00401_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00402_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00403_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00404_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00405_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00406_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00407_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00408_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00409_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00410_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00412_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00414_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00415_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00416_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00417_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00418_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00419_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00420_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00421_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00422_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00425_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00426_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00427_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00428_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00429_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00430_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00431_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00432_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00433_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00434_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00435_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00436_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00437_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00438_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00439_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00440_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00441_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00442_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00444_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00445_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00446_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00447_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00448_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00450_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00451_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00452_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00453_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00454_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00455_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00456_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00457_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00458_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00459_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00460_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00461_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00462_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00463_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00465_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00466_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00467_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00468_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00470_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00471_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00472_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00473_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00474_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00475_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00477_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00478_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00480_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00481_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00482_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00483_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00484_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00485_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00486_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00487_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00488_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00489_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00490_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00491_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00492_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00493_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00494_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00495_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00496_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00497_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00498_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00499_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00500_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00501_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00503_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00504_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00505_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00506_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00507_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00509_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00510_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00511_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00512_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00513_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00514_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00515_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00516_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00517_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00519_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00520_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00521_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00522_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00523_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00524_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00525_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00526_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00527_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00528_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00529_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00530_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00531_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00532_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00533_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00534_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00535_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00536_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00537_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00538_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00539_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00541_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00542_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00543_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00544_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00545_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00546_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00547_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00548_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00549_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00550_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00551_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00552_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00553_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00554_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00555_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00556_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00557_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00558_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00559_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00560_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00561_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00562_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00563_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00564_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00565_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00566_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00567_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00568_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00569_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00570_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00571_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00572_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00573_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00574_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00575_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00576_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00577_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00578_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00580_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00581_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00582_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00583_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00584_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00585_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00586_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00587_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00588_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00589_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00590_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00591_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00592_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00593_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00594_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00595_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00596_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00597_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00598_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00599_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00600_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00601_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00602_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00603_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00604_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00605_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00606_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00607_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00608_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00609_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00611_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00612_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00613_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00614_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00615_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00616_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00617_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00618_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00620_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00621_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00622_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00623_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00624_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00625_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00626_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00627_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00628_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00629_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00630_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00631_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00632_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00633_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00634_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00635_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00636_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00637_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00638_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00639_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00640_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00641_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00642_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00643_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00644_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00645_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00646_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00647_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00648_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00649_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00650_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00651_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00652_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00653_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00654_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00655_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00656_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00657_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00658_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00659_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00660_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00661_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00662_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00663_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00664_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00665_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00666_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00667_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00668_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00669_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00673_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00674_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00675_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00676_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00677_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00678_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00679_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00680_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00681_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00682_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00683_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00684_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00686_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00687_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00688_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00689_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00690_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00691_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00692_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00693_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00696_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00698_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00699_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00700_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00701_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00702_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00703_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00704_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00705_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00706_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00707_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00708_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00711_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00712_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00713_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00714_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00715_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00716_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00718_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00720_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00721_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00722_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00723_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00724_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00725_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00726_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00727_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00728_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00729_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00730_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00731_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00733_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00734_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00735_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00736_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00737_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00739_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00740_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00741_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00742_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00743_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00744_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00745_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00746_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00747_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00748_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00749_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00750_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00752_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00753_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00754_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00755_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00756_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00757_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00758_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00759_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00761_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00762_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00763_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00764_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00765_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00766_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00767_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00768_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00769_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00770_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00771_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00772_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00773_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00774_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00775_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00776_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00777_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00778_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00779_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00780_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00782_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00783_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00784_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00785_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00786_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00787_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00788_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00789_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00790_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00791_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00792_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00793_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00794_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00795_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00796_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00797_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00798_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00799_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00800_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00801_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00802_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00803_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00804_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00806_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00807_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00808_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00809_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00810_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00811_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00812_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00813_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00814_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00815_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00816_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00817_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00818_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00820_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00821_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00822_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00823_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00824_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00825_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00826_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00827_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00828_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00830_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00831_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00832_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00833_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00834_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00835_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00836_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00837_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00838_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00839_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00840_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00841_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00842_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00843_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00844_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00845_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00846_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00847_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00848_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00849_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00851_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00852_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00853_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00854_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00856_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00857_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00858_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00859_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00860_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00862_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00863_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00864_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00865_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00866_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00867_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00868_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00869_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00870_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00871_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00872_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00873_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00874_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00875_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00876_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00877_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00878_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00879_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00880_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00881_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00882_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00883_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00884_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00885_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00886_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00887_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00888_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00890_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00891_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00892_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: generated/00893_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00894_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00895_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00896_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00897_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: generated/00898_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: generated/00899_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00900_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: generated/00901_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: generated/00902_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: generated/00903_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: generated/00905_NR_0_NID_2_ER_0_EID_6.gexf
# ...
#   inflating: test/00805.gexf
#   inflating: test/00819.gexf
#   inflating: test/00829.gexf
#   inflating: test/00850.gexf
#   inflating: test/00855.gexf
#   inflating: test/00861.gexf
#   inflating: test/00889.gexf
#   inflating: test/00904.gexf
#   inflating: test/00921.gexf
#   inflating: test/00929.gexf
#   inflating: test/00947.gexf
#   inflating: test/00954.gexf
#   inflating: test/00963.gexf
#   inflating: test/00971.gexf
#   inflating: test/00975.gexf
#   inflating: test/01001.gexf
#   inflating: test/01015.gexf
#   inflating: test/01016.gexf
#   inflating: test/01023.gexf
#   inflating: test/01027.gexf
#   inflating: test/01050.gexf
#   inflating: test/01066.gexf
#   inflating: test/01081.gexf
#   inflating: test/01091.gexf
#   inflating: test/01095.gexf
#   inflating: test/01096.gexf
#   inflating: test/01102.gexf
#   inflating: test/01115.gexf
#   inflating: test/01121.gexf
#   inflating: test/01133.gexf
#   inflating: test/01134.gexf
#   inflating: test/01143.gexf
#   inflating: test/01150.gexf
#   inflating: test/01160.gexf
#   inflating: test/01161.gexf
#   inflating: test/01186.gexf
#   inflating: test/01195.gexf
#   inflating: test/01206.gexf
#   inflating: test/01238.gexf
#   inflating: test/01269.gexf
#   inflating: test/01285.gexf
#   inflating: test/01295.gexf
#   inflating: test/01296.gexf
#   inflating: test/01309.gexf
#   inflating: test/01323.gexf
#   inflating: test/01324.gexf
#   inflating: test/01328.gexf
#   inflating: test/01330.gexf
#   inflating: test/01337.gexf
#   inflating: test/01341.gexf
#   inflating: test/01362.gexf
#   inflating: test/01371.gexf
#   inflating: test/01392.gexf
#   inflating: test/01404.gexf
#   inflating: test/01420.gexf
#   inflating: test/01425.gexf
#   inflating: test/01428.gexf
#   inflating: test/01440.gexf
#   inflating: test/01457.gexf
#   inflating: test/01459.gexf
#   inflating: test/01462.gexf
#   inflating: test/01469.gexf
#   inflating: test/01473.gexf
#   inflating: test/01483.gexf
#   inflating: test/01512.gexf
#   inflating: test/01523.gexf
#   inflating: test/01535.gexf
#   inflating: test/01541.gexf
#   inflating: test/01543.gexf
#   inflating: test/01573.gexf
#   inflating: test/01578.gexf
#   inflating: test/01587.gexf
#   inflating: test/01590.gexf
#   inflating: test/01591.gexf
#   inflating: test/01595.gexf
#   inflating: test/01598.gexf
#   inflating: test/01603.gexf
#   inflating: test/01608.gexf
#   inflating: test/01618.gexf
#   inflating: test/01650.gexf
#   inflating: test/01656.gexf
#   inflating: test/01659.gexf
#   inflating: test/01660.gexf
#   inflating: test/01675.gexf
#   inflating: test/01678.gexf
#   inflating: test/01689.gexf
#   inflating: test/01691.gexf
#   inflating: test/01692.gexf
#   inflating: test/01709.gexf
#   inflating: test/01713.gexf
#   inflating: test/01769.gexf
#   inflating: test/01772.gexf
#   inflating: test/01774.gexf
#   inflating: test/01776.gexf
#   inflating: test/01792.gexf
#   inflating: test/01797.gexf
#   inflating: test/01815.gexf
#   inflating: test/01825.gexf
#   inflating: test/01836.gexf
#   inflating: test/01854.gexf
#   inflating: test/01886.gexf
#   inflating: test/01888.gexf
#   inflating: test/01901.gexf
#   inflating: test/01918.gexf
#   inflating: test/01938.gexf
#   inflating: test/01951.gexf
#   inflating: test/01954.gexf
#   inflating: test/01960.gexf
#   inflating: test/01969.gexf
#   inflating: test/01977.gexf
#   inflating: test/02004.gexf
#   inflating: test/02022.gexf
#   inflating: test/02024.gexf
#   inflating: test/02042.gexf
#   inflating: test/02052.gexf
#   inflating: test/02066.gexf
#   inflating: test/02073.gexf
#   inflating: test/02078.gexf
#   inflating: test/02084.gexf
#   inflating: test/02085.gexf
#   inflating: test/02115.gexf
#   inflating: test/02117.gexf
#   inflating: test/02140.gexf
#   inflating: test/02147.gexf
#   inflating: test/02179.gexf
#   inflating: test_gen/00010_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00029_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/00030_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00039_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00073_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00094_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00098_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00104_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00118_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00124_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00125_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00130_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00147_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00163_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00170_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/00176_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/00181_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/00188_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00198_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00203_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00215_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/00216_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00218_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00224_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00248_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00272_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00290_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00305_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00337_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00338_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00340_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/00346_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/00348_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/00358_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/00364_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00383_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/00386_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00395_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00411_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00413_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00423_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00424_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00443_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00449_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/00464_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/00469_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00476_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00479_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00502_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00508_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00518_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00540_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00579_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00610_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/00619_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00670_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00671_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00672_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00685_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00694_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00695_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00697_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/00709_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00710_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00717_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00719_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/00732_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00738_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00751_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00760_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/00781_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00805_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00819_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00829_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00850_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00855_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00861_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00889_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/00904_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/00921_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/00929_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00947_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/00954_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/00963_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00971_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/00975_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01001_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01015_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01016_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01023_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01027_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01050_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01066_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01081_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01091_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01095_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01096_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01102_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01115_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01121_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01133_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01134_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01143_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01150_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01160_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01161_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01186_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01195_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01206_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01238_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01269_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01285_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01295_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01296_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01309_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01323_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01324_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01328_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01330_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01337_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01341_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01362_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01371_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01392_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01404_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01420_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01425_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01428_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01440_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01457_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01459_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01462_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01469_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01473_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01483_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01512_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01523_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01535_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01541_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01543_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01573_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01578_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01587_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01590_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01591_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01595_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01598_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01603_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01608_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01618_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01650_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01656_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01659_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01660_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01675_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01678_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01689_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01691_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01692_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01709_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01713_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01769_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01772_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01774_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/01776_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/01792_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01797_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01815_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01825_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01836_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/01854_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01886_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01888_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01901_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01918_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01938_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/01951_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/01954_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01960_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/01969_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/01977_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: test_gen/02004_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/02022_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/02024_NR_0_NID_7_ER_0_EID_1.gexf
#   inflating: test_gen/02042_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/02052_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/02066_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/02073_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/02078_NR_0_NID_2_ER_0_EID_6.gexf
#   inflating: test_gen/02084_NR_0_NID_1_ER_0_EID_7.gexf
#   inflating: test_gen/02085_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/02115_NR_0_NID_5_ER_0_EID_3.gexf
#   inflating: test_gen/02117_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/02140_NR_0_NID_3_ER_0_EID_5.gexf
#   inflating: test_gen/02147_NR_0_NID_4_ER_0_EID_4.gexf
#   inflating: test_gen/02179_NR_0_NID_6_ER_0_EID_2.gexf
#   inflating: testing_pairs.csv
#   inflating: training_pairs.csv

# %%
DATASET = "LINUX"
ORI_DIR = "/content/original"
GEN_DIR ="/content/generated"
TEST_DIR = "/content/test"
TEST_GEN_DIR = "/content/test"
DATASET_FOLDER = "/content"

# %%
# test_csv = pd.DataFrame(test_data, columns=['G1', 'G2', 'gt_ged']).to_csv(DATASET_FOLDER + "/testing_pairs.csv",
#                                                                           index=False)
def load_pairs():
    train_pairs = []
    train_csv = pd.read_csv(DATASET_FOLDER+"/training_pairs.csv")
    for index, row in train_csv.iterrows():
        file1 = row['G1']
        file2 = row['G2']
        ged =ast.literal_eval(row['GED'])
        new_ged = [ged[1],ged[3]]
        gt_ged = row['gt_ged']
        graph1 = nx.read_gexf(path=ORI_DIR + '/' + file1)
        graph2 = nx.read_gexf(path=GEN_DIR + '/' + file2)
        train_pairs.append({"graph_pair": [graph1, graph2], "ged": new_ged, "gt_ged":gt_ged})


    test_pairs = []
    test_csv = pd.read_csv(DATASET_FOLDER+"/testing_pairs.csv")
    for index, row in test_csv.iterrows():
        file1 = row['G2']
        file2 = row['G1']
        gt_ged = row['gt_ged']
        graph1 = nx.read_gexf(path=TEST_GEN_DIR + '/' + file1)
        graph2 = nx.read_gexf(path=TEST_DIR + '/' + file2)
        test_pairs.append({"graph_pair": [graph1, graph2], "gt_ged": gt_ged})
    return train_pairs, test_pairs
train_pairs, test_pairs = load_pairs()
print(len(train_pairs))
print(train_pairs[0])
print(len(test_pairs))
print(test_pairs[0])
# Out:
# 2001
# {'graph_pair': [<networkx.classes.graph.Graph object at 0x7f0de0ca0fd0>, <networkx.classes.graph.Graph object at 0x7f0de0c7fa10>], 'ged': [7, 1], 'gt_ged': 8}
# 70
# {'graph_pair': [<networkx.classes.graph.Graph object at 0x7f0dd7b4df10>, <networkx.classes.graph.Graph object at 0x7f0dd7ae5410>], 'gt_ged': 11.0}

# %%
import torch
import numpy as np


class TensorNetworkModule(torch.nn.Module):
    def __init__(self, tensor_neurons, input_dim):
        super(TensorNetworkModule, self).__init__()
        self.input_dim = input_dim
        self.tensor_neurons = tensor_neurons
        self.setup_weights()
        self.init_parameters()

    def setup_weights(self):
        self.weight_matrix = torch.nn.Parameter(torch.Tensor(self.input_dim, self.input_dim, self.tensor_neurons))
        self.weight_matrix_block = torch.nn.Parameter(torch.Tensor(self.tensor_neurons, 2 * self.input_dim))
        self.bias = torch.nn.Parameter(torch.Tensor(self.tensor_neurons, 1))

    def init_parameters(self):
        torch.nn.init.xavier_uniform_(self.weight_matrix)
        torch.nn.init.xavier_uniform_(self.weight_matrix_block)
        torch.nn.init.xavier_uniform_(self.bias)

    def forward(self, embedding_1, embedding_2):
        scoring = torch.mm(torch.t(embedding_1), self.weight_matrix.view(self.input_dim, -1))
        scoring = scoring.view(self.input_dim, self.tensor_neurons)
        scoring = torch.mm(torch.t(scoring), embedding_2)
        combined_representation = torch.cat((embedding_1, embedding_2))
        block_scoring = torch.mm(self.weight_matrix_block, combined_representation)
        scores = torch.nn.functional.relu(scoring + block_scoring + self.bias)
        return scores


def graph_aggregation_layer(input, adj):
    result = torch.mm(adj, input)
    return result

# %% [markdown]
# #No insert/delete

# %%
class TaGSim_noID(torch.nn.Module):
    def __init__(self, number_of_node_labels, number_of_edge_labels, tensor_neurons, bottle_neck_neurons):
        super(TaGSim_noID, self).__init__()
        # self.number_of_node_labels = len(number_of_node_labels)
        # self.number_of_edge_labels = len(number_of_edge_labels)
        self.tensor_neurons = tensor_neurons
        self.bottle_neck_neurons = bottle_neck_neurons
        self.setup_layers()



    def setup_layers(self):
        self.feature_count = self.tensor_neurons

        # self.tensor_network_nc = TensorNetworkModule(self.tensor_neurons, 2 * self.number_of_node_labels)
        self.tensor_network_in = TensorNetworkModule(self.tensor_neurons, 7)
        # self.tensor_network_ie = TensorNetworkModule(self.tensor_neurons, 2 * self.number_of_node_labels)
        self.tensor_network_ec = TensorNetworkModule(self.tensor_neurons, 23)

        # self.fully_connected_first_nc = torch.nn.Linear(self.feature_count, self.bottle_neck_neurons)
        # self.fully_connected_second_nc = torch.nn.Linear(self.bottle_neck_neurons, 8)
        # self.fully_connected_third_nc = torch.nn.Linear(8, 4)
        # self.scoring_layer_nc = torch.nn.Linear(4, 1)

        self.fully_connected_first_in = torch.nn.Linear(self.feature_count, self.bottle_neck_neurons)
        self.fully_connected_second_in = torch.nn.Linear(self.bottle_neck_neurons, 8)
        self.fully_connected_third_in = torch.nn.Linear(8, 4)
        self.scoring_layer_in = torch.nn.Linear(4, 1)

        # self.fully_connected_first_ie = torch.nn.Linear(self.feature_count, self.bottle_neck_neurons)
        # self.fully_connected_second_ie = torch.nn.Linear(self.bottle_neck_neurons, 8)
        # self.fully_connected_third_ie = torch.nn.Linear(8, 4)
        # self.scoring_layer_ie = torch.nn.Linear(4, 1)

        self.fully_connected_first_ec = torch.nn.Linear(self.feature_count, self.bottle_neck_neurons)
        self.fully_connected_second_ec = torch.nn.Linear(self.bottle_neck_neurons, 8)
        self.fully_connected_third_ec = torch.nn.Linear(8, 4)
        self.scoring_layer_ec = torch.nn.Linear(4, 1)

    def gal_pass(self, edge_index, features):
        hidden1 = graph_aggregation_layer(features, edge_index)
        hidden2 = graph_aggregation_layer(hidden1, edge_index)
        return hidden1, hidden2

    def transform_label_multiset(self, graph_pair, type_specified=True):
        graph1 = graph_pair['graph_pair'][0]
        graph2 = graph_pair['graph_pair'][1]
        ged = graph_pair['ged']
        
        label_multiset = dict()
        node_features_1, node_features_2= [], []

        for i in graph1.nodes():
            node_features_1.append([1.0])
        for i in graph2.nodes():
            node_features_2.append([1.0])

        node_features_1, node_features_2 = torch.FloatTensor(np.array(node_features_1)), torch.FloatTensor(
            np.array(node_features_2))

        #label_multiset["edge_index_1"], label_multiset["edge_index_2"] = nx.adjacency_matrix(graph1), nx.adjacency_matrix(graph2)
        label_multiset["features_1"], label_multiset["features_2"] = node_features_1, node_features_2

        # label_multiset["node_index_1"], label_multiset["node_index_2"] = nx.adjacency_matrix(
        #     graph1), nx.adjacency_matrix(graph2)
        # label_multiset["node_features_1"], label_multiset["node_features_2"] = node_features_1, node_features_2
        # label_multiset["edge_features_1"], label_multiset["edge_features_2"] = edge_features_1, edge_features_2
        # label_multiset["edge_adj_1"], label_multiset["edge_adj_2"] = edge_adj_1, edge_adj_2

        edges1 = list(graph1.edges())
        edges2 = list(graph2.edges())

        node_features_1, node_features_2, edge_features_1, edge_features_2, edge_adj_1, edge_adj_2 = [], [], [], [], [], []

        for i in graph1.nodes():
            node_features_1.append([1.0  ])
        for i in graph2.nodes():
            node_features_2.append([1.0  ])
            

        for i in edges1:
            edge_features_1.append([1.0 ])
            adj_row = []
            for d in edges1:
                if (i == d):
                    adj_row.append(0.0)
                    continue
                if ((i[0] in d) | (i[1] in d)):
                    adj_row.append(1.0)
                else:
                    adj_row.append(0.0)
            edge_adj_1.append(adj_row)
        for i in edges2:
            edge_features_2.append([1.0  ])
            adj_row = []
            for d in edges2:
                if (i == d):
                    adj_row.append(0.0)
                    continue
                if ((i[0] in d) | (i[1] in d)):
                    adj_row.append(1.0)
                else:
                    adj_row.append(0.0)
            edge_adj_2.append(adj_row)
        edge_features_1, edge_features_2 = torch.FloatTensor(np.array(edge_features_1)), torch.FloatTensor(
            np.array(edge_features_2))
        edge_adj_1, edge_adj_2 = torch.FloatTensor(np.array(edge_adj_1)), torch.FloatTensor(np.array(edge_adj_2))


        label_multiset["edge_features_1"], label_multiset["edge_features_2"] = edge_features_1, edge_features_2
        label_multiset["edge_adj_1"], label_multiset["edge_adj_2"] = edge_adj_1, edge_adj_2

        node_features_1,node_features_2=        nx.adjacency_matrix(graph1).todense(), nx.adjacency_matrix(graph2).todense()
        #label_multiset["edge_index_1"], label_multiset["edge_index_2"] = nx.adjacency_matrix(graph1), nx.adjacency_matrix(graph2)
        label_multiset["node_adj_1"], label_multiset["node_adj_2"] =torch.FloatTensor(np.array(node_features_1)), torch.FloatTensor(
            np.array(node_features_2))
        
        if (type_specified):  # for training
            avg_node_number = 0.5 * (graph1.number_of_nodes() + graph2.number_of_nodes())
            norm_ged = [n / avg_node_number for n in ged]
            norm_ged = np.array(norm_ged)
            label_multiset["target"] = torch.from_numpy(np.exp(-norm_ged)).view(1, -1).float()

            norm_gt_ged = (sum(ged)) / (0.5 * (graph1.number_of_nodes() + graph2.number_of_nodes()))
            label_multiset["gt_ged"] = torch.from_numpy(np.exp(-norm_gt_ged).reshape(1, 1)).view(1, -1).float()
        else:  # for testing
            norm_gt_ged = (ged) / (0.5 * (graph1.number_of_nodes() + graph2.number_of_nodes()))
            label_multiset["gt_ged"] = torch.from_numpy(np.exp(-norm_gt_ged).reshape(1, 1)).view(1, -1).float()

        return label_multiset
    def forward(self, label_multiset):
      adj_1 =  label_multiset["edge_adj_1"]
      adj_2 =  label_multiset["edge_adj_2"] 
      adj_1 =  label_multiset["node_adj_1"]
      adj_2 =  label_multiset["node_adj_2"] 
      features_1, features_2 = label_multiset["features_1"],label_multiset["features_2"]
      edge_adj_1, edge_adj_2 = label_multiset["edge_adj_1"], label_multiset["edge_adj_2"]
      
      edge_features_1, edge_features_2 = label_multiset["edge_features_1"], label_multiset["edge_features_2"]

              
      graph1_hidden1, graph1_hidden2 = self.gal_pass(adj_1, features_1)#
      graph2_hidden1, graph2_hidden2 = self.gal_pass(adj_2, features_2)#
    
      Graph1_hidden1, Graph1_hidden2, Graph2_hidden1, Graph2_hidden2 = [], [], [], []
      for i in range(graph1_hidden1.size()[0]):
        if(graph1_hidden1[i][0] >= 6):# 10 for imdb; 6 for linux # the valus here can be set by the users
            Graph1_hidden1.append([0.0]*5 + [1.0])
        else:
            Graph1_hidden1.append([1.0 if graph1_hidden1[i][0] == j else 0.0 for j in range(6)])

        if(graph1_hidden2[i][0] >= 15):# 50 for imdb; 15 for linux # the valus here can be set by the users
            Graph1_hidden2.append([0.0]*14 + [1.0])
        else:
            Graph1_hidden2.append([1.0 if graph1_hidden2[i][0] == j else 0.0 for j in range(15)])

      for i in range(graph2_hidden1.size()[0]):
          if(graph2_hidden1[i][0] >= 6):# 10 for imdb; 6 for linux # the valus here can be set by the users
              Graph2_hidden1.append([0.0]*5 + [1.0])
          else:
              Graph2_hidden1.append([1.0 if graph2_hidden1[i][0] == j else 0.0 for j in range(6)])

          if(graph2_hidden2[i][0] >= 15):# 50 for imdb; 15 for linux # the valus here can be set by the users
              Graph2_hidden2.append([0.0]*14 + [1.0])
          else:
              Graph2_hidden2.append([1.0 if graph2_hidden2[i][0] == j else 0.0 for j in range(15)])
      Graph1_hidden1, Graph1_hidden2 = torch.FloatTensor(np.array(Graph1_hidden1)), torch.FloatTensor(np.array(Graph1_hidden2))
      Graph2_hidden1, Graph2_hidden2 = torch.FloatTensor(np.array(Graph2_hidden1)), torch.FloatTensor(np.array(Graph2_hidden2))


      edge1_hidden1, edge1_hidden2 = self.gal_pass(edge_adj_1, edge_features_1)  #original edge node
      edge2_hidden1, edge2_hidden2 = self.gal_pass(edge_adj_2, edge_features_2)  #generated graph edge


      graph1_01concat = torch.cat([features_1, Graph1_hidden1], dim=1)
      graph2_01concat = torch.cat([features_2, Graph2_hidden1], dim=1)
      graph1_12concat = torch.cat([Graph1_hidden1, Graph1_hidden2], dim=1)
      graph2_12concat = torch.cat([Graph2_hidden1, Graph2_hidden2], dim=1)

      graph1_01pooled = torch.sum(graph1_01concat, dim=0).unsqueeze(1)# default: sum
      graph2_01pooled = torch.sum(graph2_01concat, dim=0).unsqueeze(1)
      graph1_12pooled = torch.sum(graph1_12concat, dim=0)
      graph2_12pooled = torch.sum(graph2_12concat, dim=0)




      #scores_in = self.tensor_network_in(graph1_01pooled, graph2_01pooled)
      #scores_in = torch.t(scores_in)
#
      #scores_in = torch.nn.functional.relu(self.fully_connected_first_in(scores_in))
      #scores_in = torch.nn.functional.relu(self.fully_connected_second_in(scores_in))
      #scores_in = torch.nn.functional.relu(self.fully_connected_third_in(scores_in))
      #score_in = torch.sigmoid(self.scoring_layer_in(scores_in))


        #edge level embedding Concatenation
      edge1_01concat = torch.cat([ edge_features_1, edge1_hidden1], dim=1)
      edge2_01concat = torch.cat([ edge_features_2, edge2_hidden1], dim=1)
      #graph pooling: edge Sum
      edge1_01pooled = torch.sum(edge1_01concat, dim=0)
      edge2_01pooled = torch.sum(edge2_01concat, dim=0)

      graph1_ec_input=torch.cat([ graph1_12pooled, edge1_01pooled]).unsqueeze(1)
      graph2_ec_input=torch.cat([ graph2_12pooled, edge2_01pooled]).unsqueeze(1)
      scores_ec = self.tensor_network_ec(graph1_ec_input, graph2_ec_input)
      scores_ec = torch.t(scores_ec)

      scores_ec = torch.nn.functional.relu(self.fully_connected_first_ec(scores_ec))
      scores_ec = torch.nn.functional.relu(self.fully_connected_second_ec(scores_ec))
      scores_ec = torch.nn.functional.relu(self.fully_connected_third_ec(scores_ec))
      score_ec = torch.sigmoid(self.scoring_layer_ec(scores_ec))
                     #edge insert
      return torch.cat([ score_ec], dim=1)

# %%
model = TaGSim_noID(Node_Types, Edge_Types, tensor_neurons, bottle_neck_neurons)

graph_pair={'graph_pair':[G,G],'ged':[0,3,0,2]}
data = model.transform_label_multiset(graph_pair)
print(data)
print('-----------')
model(data)

# %%
# test_csv = pd.DataFrame(test_data, columns=['G1', 'G2', 'gt_ged']).to_csv(DATASET_FOLDER + "/testing_pairs.csv",
#                                                                           index=False)
def load_pairs():
    train_pairs = []
    train_csv = pd.read_csv(DATASET_FOLDER+"/training_pairs.csv")
    for index, row in train_csv.iterrows():
        file1 = row['G1']
        file2 = row['G2']
        ged =ast.literal_eval(row['GED'])
        new_ged = [ged[3]]
        graph1 = nx.read_gexf(path=ORI_DIR + '/' + file1)
        graph2 = nx.read_gexf(path=GEN_DIR + '/' + file2)
        gt_ged = row['gt_ged']-abs(graph1.number_of_nodes() -graph2.number_of_nodes())
        train_pairs.append({"graph_pair": [graph1, graph2], "ged": new_ged, "gt_ged":gt_ged})


    test_pairs = []
    test_csv = pd.read_csv(DATASET_FOLDER+"/testing_pairs.csv")
    for index, row in test_csv.iterrows():
        file1 = row['G2']
        file2 = row['G1']
        graph1 = nx.read_gexf(path=TEST_GEN_DIR + '/' + file1)
        graph2 = nx.read_gexf(path=TEST_DIR + '/' + file2)
        gt_ged = row['gt_ged']-abs(graph1.number_of_nodes()- graph2.number_of_nodes())
        test_pairs.append({"graph_pair": [graph1, graph2], "gt_ged": gt_ged})
    return train_pairs, test_pairs
train_pairs, test_pairs = load_pairs()
print(len(train_pairs))
print(train_pairs[0])
print(len(test_pairs))
print(test_pairs[0])
# Out:
# 2001
# {'graph_pair': [<networkx.classes.graph.Graph object at 0x7fa9d07ac250>, <networkx.classes.graph.Graph object at 0x7fa9d07b6dd0>], 'ged': [1], 'gt_ged': 1}
# 70
# {'graph_pair': [<networkx.classes.graph.Graph object at 0x7fa9c76fab10>, <networkx.classes.graph.Graph object at 0x7fa9c8cab7d0>], 'gt_ged': 6.0}

# %%
import matplotlib.pyplot as plt

epochs = 10
tensor_neurons = 16
bottle_neck_neurons = 16
batch_size = 128
dropout = 0.0
lr = 0.001
weight_decay = 0.0

Node_Types = ['1']
Edge_Types = ['1']
#collection global node label and edge label info

print("\n-------Model training---------.\n")

model = TaGSim_noID(Node_Types, Edge_Types, tensor_neurons, bottle_neck_neurons)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
iteration = 0

visual_loss_train = []
visual_loss_test = []
train_pair = []
test_pair = []
epo = []
#model training
for epoch in range(epochs):
  
    random.shuffle(train_pairs)
    batches = []
    for graph in range(0, len(train_pairs), batch_size):
        batches.append(train_pairs[graph:graph + batch_size])
    for batch in batches:
        model.train()
        optimizer.zero_grad()
        losses = 0
        for graph_pair in batch:
            data = model.transform_label_multiset(graph_pair)
            prediction = model(data)
            losses += torch.nn.functional.mse_loss(data["target"], prediction)

        losses.backward(retain_graph=True)
        optimizer.step()
        loss = losses.item()
        print('Iteration', iteration, 'loss: ', loss / len(batch))
        iteration += 1

    visual_loss_train.append(loss / len(batch))


    # testing
    model.eval()
    test_scores=[]
    for n in test_pairs:
        graph1 = n['graph_pair'][0]  #updated_test
        graph2 = n['graph_pair'][1]  #updated_test
        ged = int(n['gt_ged'])
        tem_data = {"graph_pair": [graph1, graph2], "ged": ged}
        data = model.transform_label_multiset(tem_data, type_specified=False)
        prediction = model(data)
        prediction = torch.exp(torch.sum(torch.log(prediction))).view(1, -1)
        current_error = torch.nn.functional.mse_loss(prediction, data["gt_ged"])
        test_scores.append(current_error.data.item())
    visual_loss_test.append(sum(test_scores) / len(test_scores))
    epo.append(epoch + 1)


#visualization of traning and testing loss
plt.plot(epo, visual_loss_train, 'g', label='Training Loss')
plt.plot(epo, visual_loss_test, 'b', label='Validation Loss')
plt.title('Evaluation of TaGSim Model Without NID Process (' + DATASET + ')')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

print("\n-------Model testing---------.\n")

model.eval()
test_scores = []
for n in test_pairs:
    graph1 = n['graph_pair'][0]  #updated_test
    graph2 = n['graph_pair'][1]  #updated_test
    ged = int(n['gt_ged'])
    tem_data = {"graph_pair": [graph1, graph2], "ged": ged}
    data = model.transform_label_multiset(tem_data, type_specified=False)
    prediction = model(data)
    #prediction = torch.exp(torch.sum(torch.log(prediction))).view(1, -1)
    prediction = torch.sum(prediction).view(1, -1)
    current_error = torch.nn.functional.mse_loss(prediction, data["gt_ged"])
    test_scores.append(current_error.data.item())

model_error = sum(test_scores) / len(test_scores)
print("\nModel test error: " + str(model_error))
